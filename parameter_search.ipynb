# %%
import numpy as np
import pandas as pd
import os

# %%
DPATH = 'table/movielens'
TABLE = 'main-all-tag-weight.csv'

# %%
df = pd.read_csv(os.path.join(DPATH,TABLE))
df[df.step == 5].sort_values(by=['hr@7'],ascending=False)
# Out:
#     alpha  fold      hr@1     hr@10     hr@15     hr@20      hr@3      hr@5  \
# 23    1.0     1  0.027267  0.109550  0.134655  0.152913  0.056216  0.074474
# 59    1.0     1  0.025465  0.105946  0.133093  0.153994  0.054414  0.073153
# 35    1.0     1  0.026426  0.106306  0.131652  0.155435  0.054174  0.072312
# 47    1.0     1  0.026426  0.106186  0.130330  0.152793  0.055255  0.072793
# 17    1.0     1  0.022823  0.111111  0.139219  0.161562  0.046486  0.065946
# 11    1.0     1  0.024985  0.101742  0.124084  0.143904  0.052252  0.069550
# 5     1.0     1  0.018619  0.096817  0.120961  0.139580  0.046727  0.065345
# 29    1.0     1  0.017658  0.106907  0.139700  0.162162  0.038919  0.058619
# 41    1.0     1  0.016817  0.104745  0.139219  0.160961  0.037838  0.057297
# 53    1.0     1  0.016817  0.104264  0.139219  0.160841  0.037598  0.057057
#
#         hr@7  normalizing  prec_W  prec_item  prec_tag query sim_type  step
# ...
